# %% [markdown]
# ##### ***** Import required classes and modules

# %%
from dpk_code_quality.runtime import CodeQuality
import pandas as pd

# %% [markdown]
# ##### ***** Setup runtime parameters for this transform and invoke the transform

# %%
CodeQuality(input_folder= "test-data/input",
            output_folder= "output",
            ).transform()
# Out:
# 22:18:39 INFO - pipeline id pipeline_id
# 22:18:39 INFO - code location None
# 22:18:39 INFO - data factory data_ is using local data access: input_folder - test-data/input output_folder - output
# 22:18:39 INFO - data factory data_ max_files -1, n_sample -1
# 22:18:39 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# 22:18:39 INFO - orchestrator code_quality started at 2025-04-04 22:18:39
# 22:18:39 INFO - Number of files is 2, source profile {'max_file_size': 0.0016355514526367188, 'min_file_size': 0.001323699951171875, 'total_file_size': 0.0029592514038085938}
# tokenizer_config.json:   0%|          | 0.00/259 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/497k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/277k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/840k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# 22:18:42 INFO - Completed 1 files (50.0%) in 0.001 min
# 22:18:42 INFO - Completed 2 files (100.0%) in 0.001 min
# 22:18:42 INFO - Done processing 2 files, waiting for flush() completion.
# 22:18:42 INFO - done flushing in 0.0 sec
# 22:18:42 INFO - Completed execution in 0.046 min, execution result 0
# 0

# %%
# Load and display the output
import pandas as pd
df_output = pd.read_parquet("output/sample_1.parquet")
df_output.head()
# Out:
#                                             contents language  line_mean  \
# 0  #include <stdio.h>int main() { printf("Hello W...        C       57.0
# 1  class HelloWorld { public static void main(Str...     Java       97.0
#
#    line_max  total_num_lines  avg_longest_lines  alphanum_frac  \
# 0        57                1               57.0       0.631579
# 1        97                1               97.0       0.731959
#
#    char_token_ratio  autogenerated  config_or_test  has_no_keywords  \
# 0          3.000000          False           False            False
# 1          3.730769          False           False            False
#
#    has_few_assignments  is_xml  is_html
# 0                 True   False    False
# 1                 True   False    False
