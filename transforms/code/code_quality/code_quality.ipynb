# %% [markdown]
# ##### **** These pip installs need to be adapted to use the appropriate release level. Alternatively, The venv running the jupyter lab could be pre-configured with a requirement file that includes the right release. Example for transform developers working from git clone:
# ```
# make venv
# source venv/bin/activate
# pip install jupyterlab
# venv/bin/jupyter lab
# ```

# %%
# %%capture
## This is here as a reference only
# Users and application developers must use the right tag for the latest from pypi
# %pip install 'data-prep-toolkit-transforms[code_quality]'
! pip install pandas

# %% [markdown]
# ##### ***** Import required classes and modules

# %%
from dpk_code_quality.runtime import CodeQuality
import pandas as pd
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.

# %% [markdown]
# ##### ***** Setup runtime parameters for this transform and invoke the transform. The set of all possible parameters and their default values are [here](./README.md).

# %%
CodeQuality(input_folder= "test-data/input",
            output_folder= "output",
            ).transform()
# Out:
# 10:57:59 INFO - pipeline id pipeline_id
# 10:57:59 INFO - code location None
# 10:57:59 INFO - data factory data_ is using local data access: input_folder - test-data/input output_folder - output
# 10:57:59 INFO - data factory data_ max_files -1, n_sample -1
# 10:57:59 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# 10:57:59 INFO - orchestrator code_quality started at 2025-04-07 10:57:59
# 10:57:59 INFO - Number of files is 2, source profile {'max_file_size': 0.0016355514526367188, 'min_file_size': 0.001323699951171875, 'total_file_size': 0.0029592514038085938}
# 10:58:01 INFO - Completed 1 files (50.0%) in 0.018 min
# 10:58:01 INFO - Completed 2 files (100.0%) in 0.018 min
# 10:58:01 INFO - Done processing 2 files, waiting for flush() completion.
# 10:58:01 INFO - done flushing in 0.0 sec
# 10:58:01 INFO - Completed execution in 0.028 min, execution result 0
# 0

# %%
# Load and display the output
import pandas as pd
df_output = pd.read_parquet("output/sample_1.parquet")
df_output.head()
# Out:
#                                             contents language  line_mean  \
# 0  #include <stdio.h>int main() { printf("Hello W...        C       57.0
# 1  class HelloWorld { public static void main(Str...     Java       97.0
#
#    line_max  total_num_lines  avg_longest_lines  alphanum_frac  \
# 0        57                1               57.0       0.631579
# 1        97                1               97.0       0.731959
#
#    char_token_ratio  autogenerated  config_or_test  has_no_keywords  \
# 0          3.000000          False           False            False
# 1          3.730769          False           False            False
#
#    has_few_assignments  is_xml  is_html
# 0                 True   False    False
# 1                 True   False    False
