# %% [markdown]
# ***Comment_cleanser Transform Sample Notebook***

# %% [markdown]
# These pip installs need to be adapted to use the appropriate release level. Alternatively, The venv running the jupyter lab could be pre-configured with a requirement file that includes the right release. Example for transform developers working from git clone:
#
# make venv \
# source venv/bin/activate \
# pip install jupyterlab \
# ./python/venv/bin/jupyter lab

# %%
# %%capture
# Users and application developers must use the right tag for the latest version from pypi
# !pip install data-prep-toolkit==0.2.5.dev2
# !pip install 'data-prep-toolkit-transforms[comment_cleanser]==0.2.5.dev2'
# !pip install pandas

# %% [markdown]
# ### Configure the transform parameters.
# * Define the transform parameters required for processing. Below are the parameters specific to the Header Cleanser Transform:
#
#     * header_cleanser_contents_column_name: Column containing code to cleanse (default: contents).
#     * header_cleanser_copyright: Whether to remove copyright headers (default: True).
#     * header_cleanser_license: Whether to remove license headers (default: True).

# %%
from data_processing.runtime.pure_python import PythonTransformLauncher
from data_processing.utils import ParamsUtils
from comment_cleanser_transform_python import CommentCleanserPythonTransformConfiguration

# %% [markdown]
# ***Specify input/output folders and parameters***

# %%
# Input/output configuration
local_conf = {
    "input_folder": "path/to/your/input/folder",  # Adjust path for input files
    "output_folder": "path/to/your/output/folder",  # Adjust path for output files

# Parameters for the transform
params = {
    "data_local_config": ParamsUtils.convert_to_ast(local_conf),
    "comment_cleanser_contents_column_name": "contents"
}

# %% [markdown]
# ***Invoke the header_cleanser transformation***
# * Launch the transform using the PythonTransformLauncher.

# %%
import sys
sys.argv = ParamsUtils.dict_to_req(d=(params))  
# create launcher
launcher = PythonTransformLauncher(CommentCleanserPythonTransformConfiguration())
# launch
return_code = launcher.launch()
# Out:
# 19:13:34 INFO - pipeline id pipeline_id
# 19:13:34 INFO - code location None
# 19:13:34 INFO - data factory data_ is using local data access: input_folder - /home/yash/dead_code/data-prep-kit/transforms/code/comment_cleanser/python/test-data/input output_folder - /home/yash/dead_code/data-prep-kit/transforms/code/comment_cleanser/python/test-data
# 19:13:34 INFO - data factory data_ max_files -1, n_sample -1
# 19:13:34 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# 19:13:34 INFO - orchestrator comment_cleanser started at 2025-03-19 19:13:34
# 19:13:34 INFO - Number of files is 1, source profile {'max_file_size': 0.015672683715820312, 'min_file_size': 0.015672683715820312, 'total_file_size': 0.015672683715820312}
# 19:13:34 INFO - Running process: 5
# 19:13:34 INFO - Processing timeout: 300
# 19:13:37 INFO - Completed 1 files (100.0%) in 0.061 min
# 19:13:37 INFO - Done processing 1 files, waiting for flush() completion.
# 19:13:37 INFO - done flushing in 0.0 sec
# 19:13:37 INFO - Completed execution in 0.061 min, execution result 0

# %% [markdown]
# ***Checking the output Parquet file***

# %%
import pyarrow.parquet as pq
import pandas as pd
table = pq.read_table('path/to/parquet/file')
table.to_pandas()
# Out:
#                                              contents
# 0   # import pandas\n\n# Function to calculate the...
# 1   # Function to calculate the factorial of a num...
# 2   <!-- XML Configuration for a Web Application -...
# 3   // import java.util.Arrays;\nimport java.util....
# 4   // Function to calculate the factorial of a nu...
# 5   // #include <stdio.h>\n\n// Function to calcul...
# 6   // using System;\n\nclass Program\n{\n    // F...
# 7   // package main\n\nimport (\n    "fmt"\n)\n\n/...
# 8   # !/bin/bash\n\n# This function calculates the...
# 9   #include <stdio.h>\n\n// Function to calculate...
# 10  <!DOCTYPE html>\n<html lang="en">\n<head>\n   ...

# %%
table.to_pandas()['contents'][0]
# Out:
# '# import pandas\n\n# Function to calculate the factorial of a number using recursion\ndef factorial(n):\n    """ \n    Computes factorial of a given number.\n    Example:\n    factorial(5) => 120\n    """\n    if n == 0:\n        return 1\n    return n * factorial(n - 1)\n\n\n# TODO: Improve performance of this function (currently inefficient)\ndef slow_function():\n    # Runs an unnecessary loop with no significant operation.\n    for i in range(10000):\n        pass\n\n\n# def add_alternative(a, b):\n#     # Return the computed result.\n#     return result\n# Runs an unnecessary loop with no significant operation.\n# Black\n\n# def fibonacci(n):\n#     if n <= 1:\n#         return n\n#     return fibonacci(n - 1) + fibonacci(n - 2)\n\n\n# Variable declared but never used (can be removed)\n# unused_variable = 42\n\n\n# Debugging statement (no longer needed in production)\n# print("Debug: Checking function execution")\n# def authenticate_user(username, password):\n#     # Old authentication method, replaced with secure hashing\n#     return username == "admin" and password == "password"\n\n\n# Old sorting function (Replaced with sorted() or sort())\n# def old_sort(arr):\n#     # Deprecated: Using sorted() instead for efficiency\n#     return sorted(arr)\n\n\n# ============================\n#  Edge Cases and Valid Code\n# ============================\n\n# Function to add two numbers\ndef add(a, b):\n    """\n    Adds two integers and returns the result.\n    \n    Example:\n    add(3, 4) => 7\n    """\n    return a + b\n\n# Multi-line comment: Legacy configuration values\n"""\nLegacy settings (no longer in use)\nconfig_value = "old_value"\napi_key = "123456789"\n"""\n\n# Compute factorial of 5 and store the result\nresult = factorial(5)\n'

# %% [markdown]
# ### Notes for Users and Developers
# 1. Ensure that your input files are placed in the specified input_folder path.
#     * For sample input files, refer to the python/test-data/input folder.
# 2. Use the latest tagged version from PyPI for stability.
# 3. Transform parameters can be customized as per requirements. Update params accordingly.
