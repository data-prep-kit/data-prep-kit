# %% [markdown]
# ***Comment_cleanser Transform Sample Notebook***

# %% [markdown]
# These pip installs need to be adapted to use the appropriate release level. Alternatively, The venv running the jupyter lab could be pre-configured with a requirement file that includes the right release. Example for transform developers working from git clone:
#
# make venv \
# source venv/bin/activate \
# pip install jupyterlab \
# ./python/venv/bin/jupyter lab

# %%
# %%capture
## This is here as a reference only
# Users and application developers must use the right tag for the latest from pypi
# %pip install 'data-prep-toolkit-transforms[comment_cleanser]'
! pip install pandas

# %% [markdown]
# ### Configure the transform parameters.
# * Define the transform parameters required for processing. Below are the parameters specific to the Comment Cleanser Transform:
#
#     * comment_cleanser_contents_column_name: Column containing code to cleanse (default: contents).

# %% [markdown]
# ##### ***** Import required classes and modules

# %%
from dpk_comment_cleanser.transform_python import CommentCleanser
import pandas as pd

# %% [markdown]
# ##### ***** Setup runtime parameters for this transform and invoke the transform. The set of all possible parameters and their default values are [here](./README.md).

# %%
CommentCleanser(input_folder= "test-data/input",
            output_folder= "output",
            ).transform()
# Out:
# 11:12:41 INFO - pipeline id pipeline_id
# 11:12:41 INFO - code location None
# 11:12:41 INFO - data factory data_ is using local data access: input_folder - test-data/input output_folder - output
# 11:12:41 INFO - data factory data_ max_files -1, n_sample -1
# 11:12:41 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# 11:12:41 INFO - orchestrator comment_cleanser started at 2025-05-05 11:12:41
# 11:12:41 INFO - Number of files is 1, source profile {'max_file_size': 0.015672683715820312, 'min_file_size': 0.015672683715820312, 'total_file_size': 0.015672683715820312}
# 11:12:41 INFO - Running process: 5
# 11:12:41 INFO - Processing timeout: 300
# 11:12:46 INFO - Completed 1 files (100.0%) in 0.08 min
# 11:12:46 INFO - Done processing 1 files, waiting for flush() completion.
# 11:12:46 INFO - done flushing in 0.0 sec
# ...

# %% [markdown]
# ***Specify input/output folders and parameters***

# %%
# Load and display the output
import pandas as pd
df_output = pd.read_parquet("output/test.parquet")
df_output.head()
# Out:
#                                             contents
# 0  \n# Function to calculate the factorial of a n...
# 1  # Function to calculate the factorial of a num...
# 2  <!-- XML Configuration for a Web Application -...
# 3  import java.util.Arrays;\n\npublic class comme...
# 4  // Function to calculate the factorial of a nu...
