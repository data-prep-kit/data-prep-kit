# %% [markdown]
# ***Header_cleanser Transform Sample Notebook***

# %% [markdown]
# ##### **** These pip installs need to be adapted to use the appropriate release level. Alternatively, The venv running the jupyter lab could be pre-configured with a requirement file that includes the right release. Example for transform developers working from git clone:
# ```
# make venv
# source venv/bin/activate
# pip install jupyterlab
# venv/bin/jupyter lab
# ```

# %%
# %%capture
## This is here as a reference only
# Users and application developers must use the right tag for the latest from pypi
# %pip install 'data-prep-toolkit-transforms[header_cleanser]'
! pip install pandas

# %% [markdown]
# ##### ***** Import required classes and modules

# %%
from dpk_header_cleanser.runtime import HeaderCleanser

# %% [markdown]
# ***** Setup runtime parameters for this transform and invoke the transform. The set of all possible parameters and their default values are [here](./README.md). Specify input/output folders

# %%
HeaderCleanser(input_folder= "test-data/input",
            output_folder= "output",
            ).transform()

# %% [markdown]
# ***** Checking the output Parquet file

# %%
import pyarrow.parquet as pq
import pandas as pd
table = pq.read_table('output/test1.parquet')
table.to_pandas()

# %%
table.to_pandas()['contents'][0]
