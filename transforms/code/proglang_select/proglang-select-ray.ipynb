# %% [markdown]
# ##### **** These pip installs need to be adapted to use the appropriate release level. Alternatively, The venv running the jupyter lab could be pre-configured with a requirement file that includes the right release. Example for transform developers working from git clone:
# ```
# make venv
# source venv/bin/activate
# pip install jupyterlab
# ```

# %%
# %%capture
## This is here as a reference only
# Users and application developers must use the right tag for the latest from pypi
# %pip install "data-prep-toolkit-transforms[proglang_select]"

# %% [markdown]
# ##### **** Configure the transform parameters. The set of dictionary keys holding ProglangSelect configuration for values are as follows:
# * proglang_select_allowed_langs_file - specifies path to allowed languages file.
# * proglang_select_language_column - specifies column name that contains programming language. By default, "language" is used.
# #####

# %% [markdown]
# ##### ***** Import required classes and modules

# %%
from dpk_proglang_select.ray.transform import ProglangSelect
from data_processing.utils import GB

# %% [markdown]
# ##### ***** Setup runtime parameters and invoke the transform

# %%
# %%capture
DocQuality(input_folder='test-data/input',
            output_folder= 'output',
            run_locally= True,
            num_cpus= 0.8,
            memory= 2 * GB,
            runtime_num_workers = 3,
            runtime_creation_delay = 0,
            proglang_select_allowed_langs_file="./test-data/languages/allowed-code-languages.tx").transform()

# %% [markdown]
# ##### **** The specified folder will include the transformed parquet files.

# %%
import glob
glob.glob("output/*")
