# %%
# %%capture
## This is here as a reference only
# Users and application developers must use the right tag for the latest from pypi
# %pip install 'data-prep-toolkit-transforms[docling2prquet]'
# !pip install pandas
# !pip install -U ipywidgets

# %%
from dpk_docling2parquet.transform_python import Docling2Parquet
from data_processing.utils import GB
from dpk_docling2parquet.transform import docling2parquet_contents_types

# %%
# %%capture
x=Docling2Parquet(input_folder= "test-data/input", 
               output_folder= "output", 
               data_files_to_use=['.pdf','.zip','.xml'],          
               docling2parquet_contents_type=docling2parquet_contents_types.JSON).transform()
# Out:
# 16:26:59 INFO - docling2parquet parameters are : {'batch_size': -1, 'artifacts_path': None, 'contents_type': <docling2parquet_contents_types.JSON: 'application/json'>, 'do_table_structure': True, 'do_ocr': True, 'ocr_engine': <docling2parquet_ocr_engine.EASYOCR: 'easyocr'>, 'bitmap_area_threshold': 0.05, 'pdf_backend': <docling2parquet_pdf_backend.DLPARSE_V2: 'dlparse_v2'>, 'double_precision': 8}
# 16:26:59 INFO - pipeline id pipeline_id
# 16:26:59 INFO - code location None
# 16:26:59 INFO - data factory data_ is using local data access: input_folder - test-data/input output_folder - output
# 16:26:59 INFO - data factory data_ max_files -1, n_sample -1
# 16:26:59 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.pdf', '.zip', '.xml'], files to checkpoint ['.parquet']
# 16:26:59 INFO - orchestrator docling2parquet started at 2025-04-23 16:26:59
# 16:26:59 INFO - Number of files is 3, source profile {'max_file_size': 0.3279438018798828, 'min_file_size': 0.2757863998413086, 'total_file_size': 0.9050474166870117}
# 16:26:59 INFO - Initializing models
# 16:27:02 INFO - Completed 1 files (33.33%) in 0.002 min
# 16:27:02 INFO - Processing archive_doc_filename='2305.03393v1-pg9.pdf'
# 16:27:03 INFO - Processing archive_doc_filename='2408.09869v1-pg1.pdf'
# 16:27:03 INFO - Completed 2 files (66.67%) in 0.02 min
# 16:27:05 INFO - Completed 3 files (100.0%) in 0.049 min
# 16:27:05 INFO - Done processing 3 files, waiting for flush() completion.
# 16:27:05 INFO - done flushing in 0.0 sec
# 16:27:05 INFO - Completed execution in 0.101 min, execution result 0

# %%
import pyarrow.parquet as pq
import pandas as pd
table = pq.read_table('output/redp5110-ch1.parquet')
table.to_pandas()
# Out:
#            filename                                           contents  \
# 0  redp5110-ch1.pdf  {"schema_name":"DoclingDocument","version":"1....
#
#    num_pages  num_tables  num_doc_elements  \
# 0          5           0                57
#
#                             document_id      document_hash  ext  \
# 0  edbe7f67-3730-4bd2-a796-fa288a144499  74198560999363607  pdf
#
#                                                 hash   size  \
# 0  609845b7d3d8fa99a9dbf8f2dffbe1d83475466f6bf3b1...  38346
#
#                 date_acquired  document_convert_time   source_filename
# 0  2025-04-23T16:27:05.409071               1.787879  redp5110-ch1.pdf

# %%
#table.to_pandas()['contents'][0]
