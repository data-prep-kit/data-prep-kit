# %%
# %%capture
# !pip install 'data-prep-toolkit[ray]'
# %pip install 'data-prep-toolkit-transforms[docling2prquet]'
# !pip install pandas
# !pip install -U ipywidgets

# %%
from dpk_docling2parquet.ray.transform import Docling2Parquet
from data_processing.utils import GB
from dpk_docling2parquet.transform import docling2parquet_contents_types

# %%
# %%capture
Docling2Parquet(input_folder= "test-data/input", 
               output_folder= "output", 
               data_files_to_use=['.pdf'],
               run_locally= True,
               num_cpus= 1,
               memory= 2 * GB,
               runtime_num_workers = 2,
               docling2parquet_contents_type=docling2parquet_contents_types.JSON).transform()
# Out:
# 15:25:39 INFO - docling2parquet parameters are : {'batch_size': -1, 'artifacts_path': None, 'contents_type': <docling2parquet_contents_types.JSON: 'application/json'>, 'do_table_structure': True, 'do_ocr': True, 'ocr_engine': <docling2parquet_ocr_engine.EASYOCR: 'easyocr'>, 'bitmap_area_threshold': 0.05, 'pdf_backend': <docling2parquet_pdf_backend.DLPARSE_V2: 'dlparse_v2'>, 'double_precision': 8}
# 15:25:39 INFO - pipeline id pipeline_id
# 15:25:39 INFO - code location None
# 15:25:39 INFO - number of workers 2 worker options {'num_cpus': 1, 'memory': 2147483648, 'max_restarts': -1}
# 15:25:39 INFO - actor creation delay 0
# 15:25:39 INFO - job details {'job category': 'preprocessing', 'job name': 'docling2parquet', 'job type': 'ray', 'job id': 'job_id'}
# 15:25:39 INFO - data factory data_ is using local data access: input_folder - test-data/input output_folder - output
# 15:25:39 INFO - data factory data_ max_files -1, n_sample -1
# 15:25:39 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.pdf'], files to checkpoint ['.parquet']
# 15:25:39 INFO - Running locally
# 2025-04-23 15:25:42,082	INFO worker.py:1777 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 15:26:09 INFO - Completed execution in 0.499 min, execution result 0

# %%
import pyarrow.parquet as pq
import pandas as pd
table = pq.read_table('output/redp5110-ch1.parquet')
table.to_pandas()
# Out:
#            filename                                           contents  \
# 0  redp5110-ch1.pdf  {"schema_name":"DoclingDocument","version":"1....
#
#    num_pages  num_tables  num_doc_elements  \
# 0          5           0                57
#
#                             document_id      document_hash  ext  \
# 0  a6c09d1a-be83-4421-a6f9-09b948388f72  74198560999363607  pdf
#
#                                                 hash   size  \
# 0  609845b7d3d8fa99a9dbf8f2dffbe1d83475466f6bf3b1...  38346
#
#                 date_acquired  document_convert_time   source_filename
# 0  2025-04-23T15:25:59.119285               2.927488  redp5110-ch1.pdf

# %%
#table.to_pandas()['contents'][0]
