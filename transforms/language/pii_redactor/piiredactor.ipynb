# %% [markdown]
# ##### **** These pip installs need to be adapted to use the appropriate release level. Alternatively, The venv running the jupyter lab could be pre-configured with a requirement file that includes the right release. Example for transform developers working from git clone:
# ```
# make venv
# source venv/bin/activate
# pip install jupyterlab
# ```

# %%
# %%capture
## This is here as a reference only
# Users and application developers must use the right tag for the latest from pypi
# %pip install "data-prep-toolkit-transforms[pii_redactor]"

# %% [markdown]
# ##### **** Configure the transform parameters.
# ```
#  --pii_redactor_entities PII_ENTITIES
#                         list of PII entities to be captured for example: ["PERSON", "EMAIL"]
#  --pii_redactor_operator REDACTOR_OPERATOR
#                         Two redaction techniques are supported - replace(default), redact
#   --pii_redactor_transformed_contents PII_TRANSFORMED_CONTENT_COLUMN_NAME
#                         Mention the column name in which transformed contents will be added. This is required argument.
#   --pii_redactor_score_threshold SCORE_THRESHOLD
#                         The score_threshold is a parameter that sets the minimum confidence score required for an entity to be considered a match. Provide a value above 0.6
# ```
# #####

# %% [markdown]
# ##### ***** Import required classes and modules

# %%
from dpk_pii_redactor import PIIRedactor

# %% [markdown]
# ##### ***** Setup runtime parameters and invoke the transform

# %%
# %%capture
PIIRedactor(input_folder='ray/test-data/input',
            output_folder= 'output',
            pii_redactor_entities = ["PERSON", "EMAIL_ADDRESS"],
            pii_redactor_operator = "replace",
            pii_redactor_transformed_contents = "title").transform()
# Out:
# {"time": "15:11:45", "logger": "dpk", "logLevel": "INFO", "message": "pipeline id pipeline_id"}
# {"time": "15:11:45", "logger": "dpk", "logLevel": "INFO", "message": "code location {'github': 'UNDEFINED', 'build-date': 'UNDEFINED', 'commit_hash': 'UNDEFINED', 'path': 'UNDEFINED'}"}
# {"time": "15:11:45", "logger": "dpk", "logLevel": "INFO", "message": "data factory data_ max_files -1, n_sample -1"}
# {"time": "15:11:45", "logger": "dpk", "logLevel": "INFO", "message": "data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']"}
# {"time": "15:11:45", "logger": "dpk", "logLevel": "INFO", "message": "data factory data_ Data Access:  DataAccessLocal"}
# {"time": "15:11:45", "logger": "dpk", "logLevel": "INFO", "message": "orchestrator pii_redactor started at 2025-11-19 15:11:45"}
# {"time": "15:11:45", "logger": "dpk", "logLevel": "INFO", "message": "Number of files is 1, source profile {'max_file_size': 0.0023164749145507812, 'min_file_size': 0.0023164749145507812, 'total_file_size': 0.0023164749145507812}"}
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 11.8 MB/s eta 0:00:0031m11.9 MB/s eta 0:00:01
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# {"time": "15:11:47", "logger": "dpk", "logLevel": "INFO", "message": "Loading model from flair/ner-english-large"}
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# 2025-11-19 15:12:01,777 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-LOC, B-ORG, E-ORG, I-PER, S-PER, B-MISC, I-MISC, E-MISC, I-ORG, B-LOC, E-LOC, I-LOC, <START>, <STOP>
# {"time": "15:12:05", "logger": "dpk", "logLevel": "INFO", "message": "Completed 1 files (100.0%) in 0.043 min"}
# {"time": "15:12:05", "logger": "dpk", "logLevel": "INFO", "message": "Done processing 1 files, waiting for flush() completion."}
# {"time": "15:12:05", "logger": "dpk", "logLevel": "INFO", "message": "done flushing in 0.0 sec"}
# {"time": "15:12:05", "logger": "dpk", "logLevel": "INFO", "message": "Completed execution in 0.329 min, execution result 0"}

# %% [markdown]
# ##### **** The specified folder will include the transformed parquet files.

# %%
import glob
glob.glob("output/*")
# Out:
# ['output/metadata.json', 'output/test1.parquet']
