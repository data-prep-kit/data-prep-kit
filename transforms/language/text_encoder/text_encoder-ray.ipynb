# %% [markdown]
# ##### **** These pip installs need to be adapted to use the appropriate release level. Alternatively, The venv running the jupyter lab could be pre-configured with a requirement file that includes the right release. Example for transform developers working from git clone:
# ```
# make venv
# source venv/bin/activate
# pip install jupyterlab
# ```

# %%
# %%capture
## This is here as a reference only
# Users and application developers must use the right tag for the latest from pypi
# !pip install data-prep-toolkit[ray]
# !pip install "data-prep-toolkit-transforms[ray, text_encoder]==1.0.0a4"
# !pip install -U ipywidgets

# %% [markdown]
# ##### ***** Import required classes and modules

# %%
from dpk_text_encoder.runtime import TextEncoder
from data_processing.utils import GB
# Out:
# 2025-11-05 10:07:56,357	INFO util.py:154 -- Missing packages: ['ipywidgets']. Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.

# %% [markdown]
# ##### ***** Setup runtime parameters for this transform

# %%
x=TextEncoder(input_folder= "test-data/input/", 
               output_folder= "output/", 
               text_encoder_model_name = 'ibm-granite/granite-embedding-small-english-r2',
               text_encoder_lanceDB_data_uri = 'output/test.db/test.lance/',
               text_encoder_lanceDB_batch_size = 10,
               text_encoder_embedding_batch_size = 5,
               text_encoder_lanceDB_fragments_json_folder = 'output/fragments_json/',
               text_encoder_lanceDB_table_name = 'test'
               ).transform()
# Out:
# 10:10:06 INFO - text_encoder parameters are : {'content_column_name': 'contents', 'output_embeddings_column_name': 'embeddings', 'model_name': 'ibm-granite/granite-embedding-small-english-r2', 'model_max_seq_length': 2048, 'lanceDB_data_uri': 'output/test.db/test.lance/', 'lanceDB_batch_size': 10, 'embedding_batch_size': 5, 'lanceDB_fragments_json_folder': 'output/fragments_json/', 'lanceDB_table_name': 'test', 'embeddings_exist': False, 'embeddings_in_chunks': False, 'embeddings_max_num_chunks': 2, 'embeddings_in_parquet': False}
# 10:10:06 INFO - pipeline id pipeline_id
# 10:10:06 INFO - code location {'github': 'UNDEFINED', 'build-date': 'UNDEFINED', 'commit_hash': 'UNDEFINED', 'path': 'UNDEFINED'}
# 10:10:06 INFO - data factory data_ max_files -1, n_sample -1
# 10:10:06 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# 10:10:06 INFO - data factory data_ Data Access:  DataAccessLocal
# 10:10:06 INFO - orchestrator text_encoder started at 2025-11-05 10:10:06
# 10:10:06 INFO - Number of files is 1, source profile {'max_file_size': 0.04261493682861328, 'min_file_size': 0.04261493682861328, 'total_file_size': 0.04261493682861328}
# 10:10:06 INFO - GPU is not available. Using CPU.
# 10:10:06 INFO - self.embeddings_exist=False
# 10:10:06 INFO - self.embeddings_in_parquet=False
# 10:10:06 INFO - self.embeddings_in_chunks=False
# 10:10:06 INFO - self.model_max_seq_length=2048
# 10:10:06 INFO - self.embeddings_max_num_chunks=2
# 10:10:08 INFO - compute embeddings without chunking for /Users/kun-lungwu/outer/text-encoder/data-prep-kit/transforms/language/text_encoder/test-data/input/test1.parquet
# 10:10:10 INFO - self.input_folder='/Users/kun-lungwu/outer/text-encoder/data-prep-kit/transforms/language/text_encoder/test-data/input/' self.output_folder='/Users/kun-lungwu/outer/text-encoder/data-prep-kit/transforms/language/text_encoder/output/' writing empty_table to /Users/kun-lungwu/outer/text-encoder/data-prep-kit/transforms/language/text_encoder/output/test1.parquet
# 10:10:10 INFO - 10674 at 10:10:10 writes 15 rows to output/test.db/test.lance/.
# 10:10:10 INFO - finished embeddings for /Users/kun-lungwu/outer/text-encoder/data-prep-kit/transforms/language/text_encoder/test-data/input/test1.parquet
# 10:10:10 INFO - Completed 1 files (100.0%) in 0.044 min
# 10:10:10 INFO - Done processing 1 files, waiting for flush() completion.
# 10:10:10 INFO - done flushing in 0.0 sec
# 10:10:10 INFO - Completed execution in 0.073 min, execution result 0

# %%
import sys
sys.argv = ['dpk_text_encoder/lance_commit.py', '--lanceDB_uri', 'output/test.db', 
            'lanceDB_data_uri', 'output/test.db/test.lance',
            'lanceDB_table_name', 'test',
            'lanceDB_fragments_json_foler', 'output/fragments_json',
            'lanceDB_table_schema_folder', 'output/']
# %run dpk_text_encoder/lance_commit.py --lanceDB_uri "output/test.db" --lanceDB_data_uri "output/test.db/test.lance" --lanceDB_table_name "test" --lanceDB_fragments_json_folder "output/fragments_json/" --lanceDB_table_schema_folder "output/"
# Out:
# all_fragments_json=['{"id": 0, "files": [{"fields": [0, 1, 2], "column_indices": [0, 1, 2], "file_major_version": 2, "file_minor_version": 0, "file_size_bytes": 81245, "base_id": null, "path": "0001000110000101101001104a602d40a19fb788e11ad84d2b.lance"}], "physical_rows": 15, "deletion_file": null, "row_id_meta": null, "created_at_version_meta": null, "last_updated_at_version_meta": null}', '{"id": 0, "files": [{"fields": [0, 1, 2], "column_indices": [0, 1, 2], "file_major_version": 2, "file_minor_version": 0, "file_size_bytes": 81245, "base_id": null, "path": "10000010000001001100000105208b4d048965741c85e28cc7.lance"}], "physical_rows": 15, "deletion_file": null, "row_id_meta": null, "created_at_version_meta": null, "last_updated_at_version_meta": null}']
# total_rows=30
# file.path='output/test1.parquet'
# find schema for the lance fragments
# schema=contents: string
# document_id: string
# embeddings: fixed_size_list<element: halffloat>[384]
#   child 0, element: halffloat
# -- schema metadata --
# pandas: '{"index_columns": [{"kind": "range", "name": null, "start": 0, "' + 516
# lance commit successful.
# lanceDB_uri='output/test.db'
# table.count_rows()=30
# lance completed the commit.

# %% [markdown]
# ##### **** The specified folder will include the transformed parquet files.

# %%
import glob
glob.glob("output/*")
# Out:
# ['output/metadata.json',
#  'output/test.db',
#  'output/fragments_json',
#  'output/test1.parquet']
