# %% [markdown]
# ##### **** These pip installs need to be adapted to use the appropriate release level. Alternatively, The venv running the jupyter lab could be pre-configured with a requirement file that includes the right release. Example for transform developers working from git clone:
# ```
# make venv
# source venv/bin/activate
# pip install jupyterlab
# ```

# %%
# %%capture
## This is here as a reference only
# Users and application developers must use the right tag for the latest from pypi
# %pip install "data-prep-toolkit-transforms[ray,filter]==1.0.0a4"

# %% [markdown]
# ##### **** Configure the transform parameters. The set of dictionary keys holding DocQualityTransform configuration for values are as follows:
# * text_lang - specifies language used in the text content. By default, "en" is used.
# * doc_content_column - specifies column name that contains document text. By default, "contents" is used.
# * bad_word_filepath - specifies a path to bad word file: local folder (file or directory) that points to bad word file. You don't have to set this parameter if you don't need to set bad words.
# #####

# %% [markdown]
# ##### ***** Import required classes and modules

# %%
from dpk_filter.ray.runtime import Filter
from data_processing.utils import GB

# %% [markdown]
# ##### ***** Setup runtime parameters and invoke the transform

# %%
#%%capture
Filter(input_folder='test-data/ds01/input/parquet',
            output_folder= 'output/parquet',
            run_locally= True,
            num_cpus= 0.8,
            memory= 2 * GB,
            runtime_num_workers = 3,
            filter_columns_to_drop= ["extra", "cluster"],
            filter_criteria_list= [
                "docq_total_words > 100 AND docq_total_words < 400",
                 "ibmkenlm_docq_perplex_score < 250",
                ],
            filter_input_arrow_folder= "test-data/ds01/input/arrow",
            filter_output_arrow_folder = "output/arrow",
            filter_doc_id_column_name = "document_id",
            filter_logical_operator= "AND"
            ).transform()
# Out:
# 09:51:08 INFO - pipeline id pipeline_id
# 09:51:08 INFO - code location None
# 09:51:08 INFO - number of workers 3 worker options {'num_cpus': 0.8, 'memory': 2147483648, 'max_restarts': -1}
# 09:51:08 INFO - actor creation delay 0
# 09:51:08 INFO - job details {'job category': 'preprocessing', 'job name': 'filter', 'job type': 'ray', 'job id': 'job_id'}
# 09:51:08 INFO - data factory data_ is using local data access: input_folder - test-data/ds01/input/parquet output_folder - output/parquet
# 09:51:08 INFO - data factory data_ max_files -1, n_sample -1
# 09:51:08 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.parquet'], files to checkpoint ['.parquet']
# 09:51:08 INFO - Running locally
# 2025-03-19 09:51:09,252	INFO worker.py:1777 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# (orchestrate pid=612) 09:51:10 INFO - orchestrator started at 2025-03-19 09:51:10
# (orchestrate pid=612) 09:51:10 INFO - Number of files is 1, source profile {'max_file_size': 0.02131938934326172, 'min_file_size': 0.02131938934326172, 'total_file_size': 0.02131938934326172}
# (orchestrate pid=612) 09:51:10 INFO - Cluster resources: {'cpus': 10, 'gpus': 0, 'memory': 26.591864014044404, 'object_store': 2.0}
# (orchestrate pid=612) 09:51:10 INFO - Number of workers - 3 with {'num_cpus': 0.8, 'memory': 2147483648, 'max_restarts': -1} each
# (orchestrate pid=612) 09:51:11 INFO - Completed 0 files (0.0%)  in 0.0 min. Waiting for completion
# (orchestrate pid=612) 09:51:11 INFO - Completed processing 1 files in 0.0 min
# (orchestrate pid=612) 09:51:11 INFO - done flushing in 0.001 sec
# 09:51:21 INFO - Completed execution in 0.22 min, execution result 0
# 0

# %% [markdown]
# ##### **** The specified folder will include the transformed parquet files.

# %%
import glob
glob.glob("output/*")
# Out:
# ['output/arrow', 'output/parquet']
