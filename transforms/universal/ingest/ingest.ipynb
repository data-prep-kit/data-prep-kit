# %% [markdown]
# ##### **** These pip installs need to be adapted to use the appropriate release level. Alternatively, The venv running the jupyter lab could be pre-configured with a requirement file that includes the right release. Example for transform developers working from git clone:
# ```
# make venv
# source venv/bin/activate
# pip install jupyterlab
# ```

# %%
# %%capture
## This is here as a reference only
# Users and application developers must use the right tag for the latest from pypi
#%pip install 'data-prep-toolkit-transforms[ingest]'

# %% [markdown]
# ##### **** Configure the transform parameters. The set of dictionary keys holding IngestTransform configuration  values are as follows:
# * ...
# * ..

# %% [markdown]
# ##### ***** Import required classes and modules

# %%
from dpk_ingest.runtime import Ingest
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.

# %% [markdown]
# ##### ***** Setup runtime parameters for this transform

# %%
Ingest(input_folder= "test-data/input",
        output_folder= "output",
        data_files_to_use=['.txt','.zip']
      ).transform()
# Out:
# 11:56:56 INFO - Ingest file parameters are : {}
# 11:56:56 INFO - pipeline id pipeline_id
# 11:56:56 INFO - code location {'github': 'UNDEFINED', 'build-date': 'UNDEFINED', 'commit_hash': 'UNDEFINED', 'path': 'UNDEFINED'}
# 11:56:56 INFO - data factory data_ max_files -1, n_sample -1
# 11:56:56 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.txt', '.zip'], files to checkpoint ['.parquet']
# 11:56:56 INFO - data factory data_ Data Access:  DataAccessLocal
# 11:56:56 INFO - orchestrator ingest started at 2025-10-23 11:56:56
# 11:56:56 INFO - Number of files is 4, source profile {'max_file_size': 1.52587890625e-05, 'min_file_size': 1.33514404296875e-05, 'total_file_size': 5.7220458984375e-05}
# 11:56:56 WARNING - Exception processing file /Users/touma/developer/data-prep-kit-pkg/transforms/universal/ingest/test-data/input/l1/test1.1.txt: Traceback (most recent call last):
#   File "/Users/touma/developer/data-prep-kit-pkg/data-processing-lib/python/src/data_processing/runtime/transform_file_processor.py", line 91, in process_file
#     out_files, stats = self.transform.transform_binary(file_name=f_name, byte_array=filedata)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/touma/developer/data-prep-kit-pkg/transforms/universal/ingest/dpk_ingest/transform.py", line 77, in transform_binary
#     if TransformUtils.get_file_extension(file_name)[1] == ".zip":
#        ^^^^^^^^^^^^^^
# NameError: name 'TransformUtils' is not defined
#
# 11:56:56 INFO - Completed 1 files (25.0%) in 0.0 min
# 11:56:56 WARNING - Exception processing file /Users/touma/developer/data-prep-kit-pkg/transforms/universal/ingest/test-data/input/l1/test1.2.txt: Traceback (most recent call last):
#   File "/Users/touma/developer/data-prep-kit-pkg/data-processing-lib/python/src/data_processing/runtime/transform_file_processor.py", line 91, in process_file
#     out_files, stats = self.transform.transform_binary(file_name=f_name, byte_array=filedata)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/touma/developer/data-prep-kit-pkg/transforms/universal/ingest/dpk_ingest/transform.py", line 77, in transform_binary
#     if TransformUtils.get_file_extension(file_name)[1] == ".zip":
#        ^^^^^^^^^^^^^^
# NameError: name 'TransformUtils' is not defined
#
# 11:56:56 INFO - Completed 2 files (50.0%) in 0.0 min
# 11:56:56 WARNING - Exception processing file /Users/touma/developer/data-prep-kit-pkg/transforms/universal/ingest/test-data/input/test1.txt: Traceback (most recent call last):
#   File "/Users/touma/developer/data-prep-kit-pkg/data-processing-lib/python/src/data_processing/runtime/transform_file_processor.py", line 91, in process_file
#     out_files, stats = self.transform.transform_binary(file_name=f_name, byte_array=filedata)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/touma/developer/data-prep-kit-pkg/transforms/universal/ingest/dpk_ingest/transform.py", line 77, in transform_binary
#     if TransformUtils.get_file_extension(file_name)[1] == ".zip":
#        ^^^^^^^^^^^^^^
# NameError: name 'TransformUtils' is not defined
#
# 11:56:56 INFO - Completed 3 files (75.0%) in 0.0 min
# 11:56:56 WARNING - Exception processing file /Users/touma/developer/data-prep-kit-pkg/transforms/universal/ingest/test-data/input/test2.txt: Traceback (most recent call last):
#   File "/Users/touma/developer/data-prep-kit-pkg/data-processing-lib/python/src/data_processing/runtime/transform_file_processor.py", line 91, in process_file
#     out_files, stats = self.transform.transform_binary(file_name=f_name, byte_array=filedata)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/touma/developer/data-prep-kit-pkg/transforms/universal/ingest/dpk_ingest/transform.py", line 77, in transform_binary
#     if TransformUtils.get_file_extension(file_name)[1] == ".zip":
#        ^^^^^^^^^^^^^^
# NameError: name 'TransformUtils' is not defined
#
# 11:56:56 INFO - Completed 4 files (100.0%) in 0.0 min
# 11:56:56 INFO - Done processing 4 files, waiting for flush() completion.
# 11:56:56 INFO - done flushing in 0.0 sec
# Traceback (most recent call last):
#   File "/Users/touma/developer/data-prep-kit-pkg/data-processing-lib/python/src/data_processing/runtime/pure_python/transform_orchestrator.py", line 132, in orchestrate
#     stats["processing_time"] = round(stats["processing_time"], 3)
#                                      ~~~~~^^^^^^^^^^^^^^^^^^^
# KeyError: 'processing_time'
# 11:56:56 ERROR - Exception during execution 'processing_time': None
# 11:56:56 INFO - Completed execution in 0.0 min, execution result 1
# 1

# %% [markdown]
# ##### ***** Use python runtime to invoke the transform

# %% [markdown]
# ##### **** The specified folder will include the transformed parquet files.

# %%
import glob
glob.glob("output/*")
