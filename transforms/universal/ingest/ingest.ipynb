# %% [markdown]
# ##### **** These pip installs need to be adapted to use the appropriate release level. Alternatively, The venv running the jupyter lab could be pre-configured with a requirement file that includes the right release. Example for transform developers working from git clone:
# ```
# make venv
# source venv/bin/activate
# pip install jupyterlab
# ```

# %%
# %%capture
## This is here as a reference only
# Users and application developers must use the right tag for the latest from pypi
#%pip install 'data-prep-toolkit-transforms[ingest]'

# %% [markdown]
# ##### **** Configure the transform parameters. The set of dictionary keys holding IngestTransform configuration  values are as follows:
# * ...
# * ..

# %% [markdown]
# ##### ***** Import required classes and modules

# %%
from dpk_ingest.runtime import Ingest
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.

# %% [markdown]
# ##### ***** Setup runtime parameters for this transform

# %%
Ingest(input_folder= "test-data/input",
        output_folder= "output",
        data_files_to_use=['.txt','.zip']
      ).transform()
# Out:
# 13:33:32 INFO - Ingest file parameters are : {}
# 13:33:32 INFO - pipeline id pipeline_id
# 13:33:32 INFO - code location {'github': 'UNDEFINED', 'build-date': 'UNDEFINED', 'commit_hash': 'UNDEFINED', 'path': 'UNDEFINED'}
# 13:33:32 INFO - data factory data_ max_files -1, n_sample -1
# 13:33:32 INFO - data factory data_ Not using data sets, checkpointing False, max files -1, random samples -1, files to use ['.txt', '.zip'], files to checkpoint ['.parquet']
# 13:33:32 INFO - data factory data_ Data Access:  DataAccessLocal
# 13:33:32 INFO - orchestrator ingest started at 2025-10-23 13:33:32
# 13:33:32 INFO - Number of files is 5, source profile {'max_file_size': 0.000179290771484375, 'min_file_size': 1.33514404296875e-05, 'total_file_size': 0.00023651123046875}
# 13:33:32 INFO - Completed 1 files (20.0%) in 0.0 min
# 13:33:32 INFO - Completed 2 files (40.0%) in 0.0 min
# ...

# %% [markdown]
# ##### ***** Use python runtime to invoke the transform

# %% [markdown]
# ##### **** The specified folder will include the transformed parquet files.

# %%
import glob
glob.glob("output/*")
# Out:
# ['output/test.parquet',
#  'output/metadata.json',
#  'output/test2.parquet',
#  'output/l1']

# %%
glob.glob("output/l1/*")
# Out:
# ['output/l1/test1.2.parquet']
